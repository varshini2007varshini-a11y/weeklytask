# %% [markdown]
# # EDA_Supersales_stores
# # 9/9/2026

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
import pandas as pd

df = pd.read_csv(r"C:\\Users\\acer\\Desktop\\weekly task ds\samplesuperstore.csv")
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %%
 df # shows full dataframe or dataset records with all columns
# Out:
#        Row ID        Order ID  Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800    1/3/2023   1/7/2023  Standard Class
# 1           2  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 2           3  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 3           4  US-2023-112326    1/4/2023   1/8/2023  Standard Class
# 4           5  US-2023-141817    1/5/2023  1/12/2023  Standard Class
# ...       ...             ...         ...        ...             ...
# 10189   10190  US-2026-143259  12/30/2026   1/3/2027  Standard Class
# 10190   10191  US-2026-115427  12/30/2026   1/3/2027  Standard Class
# 10191   10192  US-2026-156720  12/30/2026   1/3/2027  Standard Class
# 10192   10193  US-2026-143259  12/30/2026   1/3/2027  Standard Class
# 10193   10194  CA-2026-143500  12/30/2026   1/3/2027  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
# First 5 rows
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800   1/3/2023   1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 2       3  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 3       4  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 4       5  US-2023-141817   1/5/2023  1/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %%
#  Last 5 rows
df.tail()
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 10189   10190  US-2026-143259  12/30/2026  1/3/2027  Standard Class
# 10190   10191  US-2026-115427  12/30/2026  1/3/2027  Standard Class
# 10191   10192  US-2026-156720  12/30/2026  1/3/2027  Standard Class
# 10192   10193  US-2026-143259  12/30/2026  1/3/2027  Standard Class
# 10193   10194  CA-2026-143500  12/30/2026  1/3/2027  Standard Class
#
#       Customer ID      Customer Name    Segment Country/Region           City  \
# 10189    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 10190    EB-13975         Erica Bern  Corporate  United States      Fairfield
# 10191    JM-15580      Jill Matthias   Consumer  United States       Loveland
# 10192    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 10193    HO-15230        Harry Olson   Consumer         Canada  Charlottetown
#
#        ... Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
# Particular rows 2
df.head(2)
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800   1/3/2023  1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326   1/4/2023  1/8/2023  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States     Houston  ...       77095
# 1  Phillina Ober  Home Office  United States  Naperville  ...       60540
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
#
#                                         Product Name   Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.448         2
# 1         GBC Standard Plastic Binding Systems Combs   3.540         2
#
#    Discount  Profit
# 0       0.2  5.5512
# 1       0.8 -5.4870
#
# [2 rows x 21 columns]

# %%
# Random 5 rows
df.sample(5)
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 5500     5501  US-2025-158568   8/29/2025    9/2/2025  Standard Class
# 5246     5247  US-2025-102561   7/18/2025   7/22/2025  Standard Class
# 10062   10063  US-2026-165841  12/21/2026  12/28/2026  Standard Class
# 1795     1796  US-2023-133830   12/5/2023  12/10/2023  Standard Class
# 326       327  US-2023-118486    4/6/2023    4/8/2023     First Class
#
#       Customer ID    Customer Name      Segment Country/Region          City  \
# 5500     RB-19465     Rick Bensley  Home Office  United States       Chicago
# 5246     NK-18490     Neil Knudson  Home Office  United States  Philadelphia
# 10062    DB-13210      Dean Braden     Consumer  United States      Paterson
# 1795     RL-19615        Rob Lucas     Consumer  United States   Los Angeles
# 326      SD-20485  Shirley Daniels  Home Office  United States  Philadelphia
#
#        ... Postal Code   Region       Product ID         Category  \
# ...

# %%
# Dataset Dimensions

print("Dataset Shape:",df.shape)
print("Number of Rows:",df.shape[0])
print("Number of Columns:",df.shape[1])
print("Total Elements:",df.size)
# Out:
# Dataset Shape: (10194, 21)
# Number of Rows: 10194
# Number of Columns: 21
# Total Elements: 214074

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State/Province     object
# Postal Code        object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
# ...

# %%
df.describe()
# Out:
#              Row ID         Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5097.500000    228.225854      3.791838      0.155385     28.673417
# std     2942.898656    619.906839      2.228317      0.206249    232.465115
# min        1.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%     2549.250000     17.220000      2.000000      0.000000      1.760800
# 50%     5097.500000     53.910000      3.000000      0.200000      8.690000
# 75%     7645.750000    209.500000      5.000000      0.200000     29.297925
# max    10194.000000  22638.480000     14.000000      0.800000   8399.976000

# %%
# Numerical columns
numerical_columns = df.select_dtypes(include=np.number).columns

print("Numerical Columns:")
print(numerical_columns)
# Out:
# Numerical Columns:
# Index(['Row ID', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %%
# Categorical Columns
categorical_columns = df.select_dtypes(include="object").columns

print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country/Region', 'City', 'State/Province',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
# Number of rows before removing null values
print("Rows before removing null values:",df.shape[0])

# Remove rows containing null values
df = df.dropna()

# Number of rows after removing null values
print("Rows after removing null values:",df.shape[0])
# Out:
# Rows before removing null values: 10194
# Rows after removing null values: 10194

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
print("Number of duplicate rows:",df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
df = df.drop_duplicates()

print("Dataset shape after removing duplicates:",df.shape)
# Out:
# Dataset shape after removing duplicates: (10194, 21)

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# %%
df[["Order Date","Ship Date"]].dtypes
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
text_columns = ["Category","Sub-Category","Segment"]

for column in text_columns:
    df[column] = (
        df[column]
        .astype(str)
        .str.strip()
        .str.title()

    )

# %%
for column in text_columns:
    print("\n",column)
    print(df[column].unique())
# Out:
#  Category
# ['Office Supplies' 'Furniture' 'Technology']
#
#  Sub-Category
# ['Paper' 'Binders' 'Labels' 'Storage' 'Art' 'Chairs' 'Fasteners' 'Phones'
#  'Furnishings' 'Accessories' 'Bookcases' 'Envelopes' 'Appliances' 'Tables'
#  'Supplies' 'Machines' 'Copiers']
#
#  Segment
# ['Consumer' 'Home Office' 'Corporate']

# %%
print("Final Shape:",df.shape)

print("\nTotal Missing Values:",df.isnull().sum().sum())

print("Total Duplicate Rows:",df.duplicated().sum())

print("\nData Types:")
print(df.dtypes)
# Out:
# Final Shape: (10194, 21)
#
# Total Missing Values: 0
# Total Duplicate Rows: 0
#
# Data Types:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State/Province            object
# Postal Code               object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
numerical_features = [
    "Sales",
    "Quantity",
    "Discount",
    "Profit"
]

df[numerical_features].describe()
# Out:
#               Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean     228.225854      3.791838      0.155385     28.673417
# std      619.906839      2.228317      0.206249    232.465115
# min        0.444000      1.000000      0.000000  -6599.978000
# 25%       17.220000      2.000000      0.000000      1.760800
# 50%       53.910000      3.000000      0.200000      8.690000
# 75%      209.500000      5.000000      0.200000     29.297925
# max    22638.480000     14.000000      0.800000   8399.976000

# %%
summary = pd.DataFrame({
    "Mean": df[numerical_features].mean(),
    "Median": df[numerical_features].median(),
    "Minimum": df[numerical_features].min(),
    "Maximum": df[numerical_features].max(),
    "Standard Deviation": df[numerical_features].std()

  })


summary
# Out:
#                 Mean  Median   Minimum    Maximum  Standard Deviation
# Sales     228.225854   53.91     0.444  22638.480          619.906839
# Quantity    3.791838    3.00     1.000     14.000            2.228317
# Discount    0.155385    0.20     0.000      0.800            0.206249
# Profit     28.673417    8.69 -6599.978   8399.976          232.465115

# %%
category_sales = (
    df.groupby("Category")["Sales"]
    .sum()
    .sort_values(ascending = False)

)

category_sales
# Out:
# Category
# Technology         839893.2790
# Furniture          754747.7613
# Office Supplies    731893.3140
# Name: Sales, dtype: float64

# %%
category_profit = (
    df.groupby("Category")["Profit"]
    .sum()
    .sort_values(ascending = False)

)

category_profit
# Out:
# Category
# Technology         146543.3756
# Office Supplies    126023.4434
# Furniture           19729.9956
# Name: Profit, dtype: float64

# %%
sub_category_profit = (
    df.groupby("Sub-Category")["Profit"]
    .sum()
    .sort_values(ascending = False)

)

sub_category_profit
# Out:
# Sub-Category
# Copiers        56093.9365
# Phones         45050.8265
# Accessories    41936.6357
# Paper          34511.5070
# Binders        31426.1003
# Chairs         27223.5323
# Storage        21285.1115
# Appliances     18329.4844
# Furnishings    13891.7430
# Envelopes       6988.0247
# Art             6653.1962
# Labels          5572.7780
# Machines        3461.9769
# Fasteners       2428.6358
# Supplies       -1171.3945
# Bookcases      -3632.0736
# Tables        -17753.2061
# Name: Profit, dtype: float64

# %%
region_profit = (
    df.groupby("Region")["Profit"]
    .sum()
    .sort_values(ascending = False)

)

region_profit
# Out:
# Region
# West       110798.8170
# East        94883.2603
# South       46749.4303
# Central     39865.3070
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Category",
    y="Sales",
    estimator="sum"
)
plt.title("Category-wise Total Sales")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Category",
    y="Profit",
    estimator="sum"
)
plt.title("Category-wise Total Profit")
plt.xlabel("Category")
plt.ylabel("Total Profit")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    y="Sales"
)

plt.title("Sales Distribution")
plt.ylabel("Sales")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    y="Profit"
)

plt.title("Profit Distribution")
plt.ylabel("Profit")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="Category",
    y="Profit"
)

plt.title("Profit Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Profit")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit"
)

plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")

plt.show()

# %%
df["Profit Margin"] = (df["Profit"] / df["Sales"])  * 100

df[["Sales","Profit","Profit Margin"]].head()
# Out:
#      Sales   Profit  Profit Margin
# 0   16.448   5.5512          33.75
# 1    3.540  -5.4870        -155.00
# 2   11.784   4.2717          36.25
# 3  272.736 -64.7748         -23.75
# 4   19.536   4.8840          25.00

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit Margin"
)

plt.title("Discount vs Profit Margin")
plt.xlabel("Discount")
plt.ylabel("Profit Margin (%)")

plt.show()

# %%
numerical_df = df.select_dtypes(include=np.number)

correlation_matrix = numerical_df.corr()

correlation_matrix
# Out:
#                  Row ID     Sales  Quantity  Discount    Profit  Profit Margin
# Row ID         1.000000 -0.008958  0.000502 -0.001474  0.003022       0.001198
# Sales         -0.008958  1.000000  0.198457 -0.027756  0.481460       0.002707
# Quantity       0.000502  0.198457  1.000000  0.007475  0.066145      -0.003830
# Discount      -0.001474 -0.027756  0.007475  1.000000 -0.218882      -0.864821
# Profit         0.003022  0.481460  0.066145 -0.218882  1.000000       0.223224
# Profit Margin  0.001198  0.002707 -0.003830 -0.864821  0.223224       1.000000

# %%
plt.figure(figsize=(10,7))

sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title("Correlation Heatmap of Numerical Attributes")

plt.show()

# %% [markdown]
# # BUSINESS INSIGHTS

# %% [markdown]
# # QUESTIONS

# %% [markdown]
# SALES INSIGHTS

# %%
1.  which category has the highest sales ?
Ans: Technology has the highest sales with approximately $839,893.28.
    
2. Which category has the lowest sales?
Ans: Office Supplies has the lowest sales with approximately $731,893.31.
    
3. Which regions contribute most to sales?
Ans: The regions ranked by sales are:
     West – $739,813.61
     East – $691,828.17
    Central – $503,170.67
     South – $391,721.91
West region contributes the most to sales.

# %% [markdown]
# PROFIT INSIGHTS

# %%
1. Which category generates the highest profit?
Ans: Technology generates the highest profit with approximately $146,543.38.
    
2. Which sub-categories have low or negative profit?
Ans: The sub-categories with negative profit are:
     Tables – -$17,753.21
     Bookcases – -$3,632.07
     Supplies – -$1,171.39
These sub-categories need improvement.

3. Which regions are most profitable?
Ans: Regions ranked by profit:
    West – $110,798.82
    East – $94,883.26
    South – $46,749.43
Central – $39,865.31
West is the most profitable region.

# %% [markdown]
# DISCOUNT INSIGHTS

# %%
1. Does profit decrease as discount increases?
Ans: Yes. The data shows that profit generally decreases when the discount increases.
    
2. Which discount levels have poor profitability?
Ans: Higher discounts, especially above 20%, show poor or negative profitability.
    
3. Which high-discount transactions generate negative profit?
Ans: High-discount transactions, particularly 30%–80% discounts, frequently generate negative profit.

# %% [markdown]
# CORRELATION INSIGHTS

# %%
1. Which variables have strong positive correlation?
Ans: Sales and Profit have the strongest positive correlation among the main variables, with a correlation of approximately 0.48.
    
2. Which variables have negative correlation?
Ans: Discount and Profit have a negative correlation of approximately -0.22.
    
3. Is Discount negatively related to Profit?
Ans: Yes. The correlation is -0.22, showing that higher discounts are generally associated with lower profit.

# %% [markdown]
# # REPORT

# %% [markdown]
# # 1. DATA SET OVERVIEW

# %%
The Superstore dataset contains information about sales, profit, products, customers and regions.
    The main aim is to analyze sales, profit, discounts and their relationships.

# %% [markdown]
# # 2. DATA PREPARATION

# %% [markdown]
# The dataset was prepared before performing the analysis. The data was loaded into Python using the Pandas library.
# The following steps were performed:
# Loaded the Superstore CSV dataset.
# Checked the number of rows and columns.
# Checked the column names and data types.
# Checked for missing values.
# Identified important numerical columns such as Sales, Quantity, Discount and Profit.
# Grouped the data based on Category, Sub-Category and Region.
# Prepared the data for further analysis and visualization.
# This preparation helped to make the dataset suitable for analysis.

# %% [markdown]
# # 3. SALES AND PROFIT ANALYSIS

# %%
Technology has the highest sales and profit 
west is the region with the highest sales and profit and sales
some sub-categories such as Tabels and Bookcases have low or negative profit

# %% [markdown]
# # 4. VISUALIZATION

# %%
Charts were used to understand the data easily. Bar charts , scatter lots and correlation
charts were used to compare sales, profit, regions and discounts.

# %% [markdown]
# # 5.DISCOUNT ANALYSIS

# %%
The analysis shows thst higher discounts generally reduce profit .
very hight discounts can result in negative profit. therefore, 
discounts should be given carefully.

# %% [markdown]
# # 6. CORRELATION ANALYSIS

# %%
Sales and profit havea position relationship. Discount and profit have a negative relationship
this shows that higher discounts are generally associated with lower profit

# %% [markdown]
# # 7 . KEY FINDINGS

# %%
* Technology has the highest sales and profit
* West is ths best-performing region
* Some sub-categories have negative profit
* High discounts reduce profitability 
* proper discount count can improve overall profit

# %% [markdown]
# # CONCLUSION

# %%
The analysis hepls identify the best categories,profitable regions and the effect of discounts.
the business can improve profit by focusing on high-performing 
products and controlling high discounts.
